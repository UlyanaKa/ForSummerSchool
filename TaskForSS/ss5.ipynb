# %%
import numpy as np

# %%
N = 100000
votings = np.random.randint(10, size=(N, 20)) # every row is 1 example of votings. every it's element if vote for candidate number j
counter = 0
for i in votings:
  if any(j not in i for j in range(10)):
    counter += 1
print(counter/N)
# Out:
# 0.78662
